# %% [markdown]
# <a href="https://www.pieriandata.com"><img src="../Pierian_Data_Logo.PNG"></a>
# <strong><center>Copyright by Pierian Data Inc.</center></strong>
# <strong><center>Created by Jose Marcial Portilla.</center></strong>

# %% [markdown]
# # Tensorboard
#
# ---
# ---
#
# **NOTE: You must watch the corresponding video to understand this lecture. This notebook can't serve as a full guide. Please watch the video BEFORE posting questions to the QA forum.**
#
# ---
# ---
#
# Let's explore the built in data visualization capabilities that come with Tensorboard.
#
# Full official tutorial available here: https://www.tensorflow.org/tensorboard/get_started
#
# ## Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../DATA/cancer_classification.csv')

# %% [markdown]
# ### Train Test Split

# %%
X = df.drop('benign_0__mal_1',axis=1).values
y = df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=101)

# %% [markdown]
# ### Scaling Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Creating the Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout

# %%
from tensorflow.keras.callbacks import EarlyStopping,TensorBoard

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
pwd
# Out:
# 'F:\\Self_Study\\ML_Basics\\ML-Basics\\17-Tensor-Flow\\ANNs'

# %% [markdown]
# ## Creating the Tensorboard Callback
#
# TensorBoard is a visualization tool provided with TensorFlow.
#
# This callback logs events for TensorBoard, including:
# * Metrics summary plots
# * Training graph visualization
# * Activation histograms
# * Sampled profiling
#
# If you have installed TensorFlow with pip, you should be able
# to launch TensorBoard from the command line:
#
# ```sh
# tensorboard --logdir=path_to_your_logs
# ```
#
# You can find more information about TensorBoard
# [here](https://www.tensorflow.org/tensorboard/).
#
#     Arguments:
#         log_dir: the path of the directory where to save the log files to be
#           parsed by TensorBoard.
#         histogram_freq: frequency (in epochs) at which to compute activation and
#           weight histograms for the layers of the model. If set to 0, histograms
#           won't be computed. Validation data (or split) must be specified for
#           histogram visualizations.
#         write_graph: whether to visualize the graph in TensorBoard. The log file
#           can become quite large when write_graph is set to True.
#         write_images: whether to write model weights to visualize as image in
#           TensorBoard.
#         update_freq: `'batch'` or `'epoch'` or integer. When using `'batch'`,
#           writes the losses and metrics to TensorBoard after each batch. The same
#           applies for `'epoch'`. If using an integer, let's say `1000`, the
#           callback will write the metrics and losses to TensorBoard every 1000
#           samples. Note that writing too frequently to TensorBoard can slow down
#           your training.
#         profile_batch: Profile the batch to sample compute characteristics. By
#           default, it will profile the second batch. Set profile_batch=0 to
#           disable profiling. Must run in TensorFlow eager mode.
#         embeddings_freq: frequency (in epochs) at which embedding layers will
#           be visualized. If set to 0, embeddings won't be visualized.

# %%
from datetime import datetime

# %%
datetime.now().strftime("%Y-%m-%d--%H%M")
# Out:
# '2024-12-31--1311'

# %%
# WINDOWS: Use "logs\\fit"
# MACOS/LINUX: Use "logs\fit"

log_directory = 'logs\\fit'

# OPTIONAL: ADD A TIMESTAMP FOR UNIQUE FOLDER
# timestamp = datetime.now().strftime("%Y-%m-%d--%H%M")
# log_directory = log_directory + '\\' + timestamp


board = TensorBoard(log_dir=log_directory,histogram_freq=1,
    write_graph=True,
    write_images=True,
    update_freq='epoch',
    profile_batch=2,
    embeddings_freq=1)

# %% [markdown]
# Now create the model layers:

# %%
model = Sequential()
model.add(Dense(units=30,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=15,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')

# %% [markdown]
# ## Train the Model

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=600,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stop,board]
          )
# Out:
# Epoch 1/600
# 14/14 [==============================] - 1s 28ms/step - loss: 0.7222 - val_loss: 0.6839
# Epoch 2/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6888 - val_loss: 0.6677
# Epoch 3/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6762 - val_loss: 0.6503
# Epoch 4/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.6585 - val_loss: 0.6323
# Epoch 5/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6446 - val_loss: 0.6141
# Epoch 6/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6181 - val_loss: 0.5933
# Epoch 7/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5947 - val_loss: 0.5658
# Epoch 8/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5799 - val_loss: 0.5333
# Epoch 9/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5773 - val_loss: 0.5034
# Epoch 10/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5344 - val_loss: 0.4678
# Epoch 11/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4878 - val_loss: 0.4292
# Epoch 12/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4687 - val_loss: 0.3916
# Epoch 13/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4698 - val_loss: 0.3666
# Epoch 14/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4424 - val_loss: 0.3462
# Epoch 15/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4434 - val_loss: 0.3233
# Epoch 16/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3893 - val_loss: 0.3050
# Epoch 17/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3876 - val_loss: 0.2832
# Epoch 18/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3772 - val_loss: 0.2731
# Epoch 19/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3372 - val_loss: 0.2572
# Epoch 20/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3519 - val_loss: 0.2409
# Epoch 21/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3404 - val_loss: 0.2273
# Epoch 22/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3257 - val_loss: 0.2149
# Epoch 23/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3067 - val_loss: 0.2013
# Epoch 24/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2962 - val_loss: 0.1918
# Epoch 25/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2829 - val_loss: 0.1810
# Epoch 26/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2984 - val_loss: 0.1760
# Epoch 27/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2840 - val_loss: 0.1668
# Epoch 28/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2652 - val_loss: 0.1609
# Epoch 29/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2543 - val_loss: 0.1568
# Epoch 30/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2311 - val_loss: 0.1488
# Epoch 31/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2612 - val_loss: 0.1428
# Epoch 32/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2450 - val_loss: 0.1520
# Epoch 33/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2495 - val_loss: 0.1372
# Epoch 34/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2284 - val_loss: 0.1337
# Epoch 35/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2075 - val_loss: 0.1309
# Epoch 36/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2325 - val_loss: 0.1275
# Epoch 37/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2142 - val_loss: 0.1371
# Epoch 38/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2227 - val_loss: 0.1226
# Epoch 39/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2156 - val_loss: 0.1187
# Epoch 40/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2124 - val_loss: 0.1300
# Epoch 41/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1935 - val_loss: 0.1233
# Epoch 42/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2028 - val_loss: 0.1134
# Epoch 43/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2118 - val_loss: 0.1158
# Epoch 44/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1984 - val_loss: 0.1112
# Epoch 45/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1995 - val_loss: 0.1065
# Epoch 46/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1753 - val_loss: 0.1110
# Epoch 47/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1525 - val_loss: 0.1034
# Epoch 48/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1597 - val_loss: 0.1000
# Epoch 49/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1681 - val_loss: 0.1053
# Epoch 50/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1795 - val_loss: 0.1008
# Epoch 51/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1823 - val_loss: 0.0958
# Epoch 52/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1654 - val_loss: 0.0957
# Epoch 53/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1870 - val_loss: 0.0958
# Epoch 54/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1523 - val_loss: 0.0939
# Epoch 55/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1599 - val_loss: 0.0972
# Epoch 56/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1339 - val_loss: 0.0935
# Epoch 57/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1594 - val_loss: 0.0871
# Epoch 58/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1670 - val_loss: 0.0941
# Epoch 59/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1624 - val_loss: 0.0995
# Epoch 60/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1567 - val_loss: 0.0905
# Epoch 61/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1353 - val_loss: 0.0902
# Epoch 62/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1504 - val_loss: 0.0902
# Epoch 63/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1491 - val_loss: 0.0860
# Epoch 64/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1256 - val_loss: 0.0954
# Epoch 65/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1435 - val_loss: 0.0890
# Epoch 66/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1603 - val_loss: 0.0857
# Epoch 67/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1377 - val_loss: 0.0890
# Epoch 68/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1404 - val_loss: 0.0951
# Epoch 69/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1474 - val_loss: 0.0882
# Epoch 70/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1534 - val_loss: 0.0847
# Epoch 71/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1319 - val_loss: 0.0856
# Epoch 72/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1290 - val_loss: 0.0824
# Epoch 73/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1387 - val_loss: 0.0825
# Epoch 74/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1295 - val_loss: 0.0840
# Epoch 75/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1396 - val_loss: 0.0913
# Epoch 76/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1172 - val_loss: 0.0864
# Epoch 77/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1373 - val_loss: 0.0953
# Epoch 78/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1193 - val_loss: 0.0835
# Epoch 79/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1433 - val_loss: 0.0840
# Epoch 80/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1144 - val_loss: 0.0846
# Epoch 81/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1254 - val_loss: 0.0869
# Epoch 82/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1218 - val_loss: 0.0789
# Epoch 83/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1270 - val_loss: 0.0835
# Epoch 84/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1089 - val_loss: 0.0792
# Epoch 85/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1166 - val_loss: 0.0918
# Epoch 86/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1125 - val_loss: 0.0934
# Epoch 87/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1107 - val_loss: 0.0769
# Epoch 88/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1292 - val_loss: 0.0790
# Epoch 89/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1117 - val_loss: 0.0876
# Epoch 90/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1426 - val_loss: 0.0778
# Epoch 91/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1146 - val_loss: 0.0906
# Epoch 92/600
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1269 - val_loss: 0.0948
# Epoch 93/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1051 - val_loss: 0.0786
# Epoch 94/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0921 - val_loss: 0.0789
# Epoch 95/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1023 - val_loss: 0.0801
# Epoch 96/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1100 - val_loss: 0.0743
# Epoch 97/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0964 - val_loss: 0.0806
# Epoch 98/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1056 - val_loss: 0.0746
# Epoch 99/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1085 - val_loss: 0.0759
# Epoch 100/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1065 - val_loss: 0.0837
# Epoch 101/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1002 - val_loss: 0.0932
# Epoch 102/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1164 - val_loss: 0.0918
# Epoch 103/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0896 - val_loss: 0.0769
# Epoch 104/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0754 - val_loss: 0.0811
# Epoch 105/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1090 - val_loss: 0.0835
# Epoch 106/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1044 - val_loss: 0.0770
# Epoch 107/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1153 - val_loss: 0.0772
# Epoch 108/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1002 - val_loss: 0.0799
# Epoch 109/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0994 - val_loss: 0.0790
# Epoch 110/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1024 - val_loss: 0.0832
# Epoch 111/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0941 - val_loss: 0.0763
# Epoch 112/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0843 - val_loss: 0.0952
# Epoch 113/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1029 - val_loss: 0.0852
# Epoch 114/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0932 - val_loss: 0.0759
# Epoch 115/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0948 - val_loss: 0.0801
# Epoch 116/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1018 - val_loss: 0.0840
# Epoch 117/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0992 - val_loss: 0.0850
# Epoch 118/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0865 - val_loss: 0.0864
# Epoch 119/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0997 - val_loss: 0.0769
# Epoch 120/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0938 - val_loss: 0.0786
# Epoch 121/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0932 - val_loss: 0.0793
# Epoch 121: early stopping

# %% [markdown]
# # Running Tensorboard

# %% [markdown]
# ## Running through the Command Line
#
# **Watch video to see how to run Tensorboard through a command line call.**

# %% [markdown]
# Tensorboard will run locally in your browser at [http://localhost:6006/](http://localhost:6006/)

# %%
print(log_directory)
# Out:
# logs\fit

# %%
pwd
# Out:
# 'F:\\Self_Study\\ML_Basics\\ML-Basics\\17-Tensor-Flow\\ANNs'

# %% [markdown]
# ### Use cd at your command line to change directory to the file path reported back by pwd or your current .py file location.
# ### Then run this code at your command line or terminal

# %%
python -m tensorboard.main --logdir logs\\fit --port 6006
# Out:
#   Cell In[21], line 1
#     python -m tensorboard.main --logdir logs\\fit --port 6006
#               ^
# SyntaxError: invalid syntax
